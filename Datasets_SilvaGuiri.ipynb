# %% [markdown]
# <a href="https://colab.research.google.com/github/machu2312/Desafio-Data-Science/blob/main/Datasets_SilvaGuiri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Set #1 - Estadisticas jugadores de la NBA de 1950 - Actualidad** 🏀
#
# ---

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/machu2312/Desafio-Data-Science/main/Seasons_Stats.csv"
df1=pd.read_csv(url,encoding='utf-8')
df1
df1.drop(['Unnamed: 0'], axis=1)
# Out:
#          Year             Player  Pos   Age   Tm     G    GS      MP   PER  \
# 0      1950.0    Curly Armstrong  G-F  31.0  FTW  63.0   NaN     NaN   NaN
# 1      1950.0       Cliff Barker   SG  29.0  INO  49.0   NaN     NaN   NaN
# 2      1950.0      Leo Barnhorst   SF  25.0  CHS  67.0   NaN     NaN   NaN
# 3      1950.0         Ed Bartels    F  24.0  TOT  15.0   NaN     NaN   NaN
# 4      1950.0         Ed Bartels    F  24.0  DNN  13.0   NaN     NaN   NaN
# ...       ...                ...  ...   ...  ...   ...   ...     ...   ...
# 24686  2017.0        Cody Zeller   PF  24.0  CHO  62.0  58.0  1725.0  16.7
# 24687  2017.0       Tyler Zeller    C  27.0  BOS  51.0   5.0   525.0  13.0
# 24688  2017.0  Stephen Zimmerman    C  20.0  ORL  19.0   0.0   108.0   7.3
# 24689  2017.0        Paul Zipser   SF  22.0  CHI  44.0  18.0   843.0   6.9
# 24690  2017.0        Ivica Zubac    C  19.0  LAL  38.0  11.0   609.0  17.0
#
# ...

# %% [markdown]
# # **Data Set #2 - Series de Netflix 🎥**

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/machu2312/Desafio-Data-Science/main/tv_series_on_netflix.csv"
df2=pd.read_csv(url,encoding='utf-8')
df2
df2.drop(['Unnamed: 0'], axis=1)
# Out:
#      show_id     type                  title         director  \
# 0         s2  TV Show          Blood & Water              NaN
# 1         s3  TV Show              Ganglands  Julien Leclercq
# 2         s4  TV Show  Jailbirds New Orleans              NaN
# 3         s5  TV Show           Kota Factory              NaN
# 4         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 2671   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 2672   s8797  TV Show             Yunus Emre              NaN
# 2673   s8798  TV Show              Zak Storm              NaN
# 2674   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 2675   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 0     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 1     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %% [markdown]
# # **Data Set #3 - Registro de conductores de micros escolares (GCBA) 🚌**

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/machu2312/Desafio-Data-Science/main/conductores-autorizados-de-servicios-escolares.csv"
df3=pd.read_csv(url,encoding='utf-8')
df3
# Out:
#      numero   fecha_vto          apellido_y_nombre numero_documento  \
# 0     C0001  2019-01-31        OTERO ESTELA ALICIA          4731265
# 1     C0002         NaN     BRUSATORI MARÍA SUSANA         12087911
# 2     C0003  2019-03-31    BOYADJIAN FABIAN ARIEL          17975234
# 3     C0004  2019-01-31      DAVERIO OSCAR GABRIEL         18160973
# 4     C0005  2018-11-30       DAPARO MARTÍN ADRIAN         25791168
# ...     ...         ...                        ...              ...
# 2433  C2446  2019-08-31        BALDO CARLOS ANIBAL         30021455
# 2434  C2447  2019-08-31        RUIZ NICOLAS MARTIN         42146105
# 2435  C2448  2019-08-31    AEDO OVALLE CARLOS OMAR         92004888
# 2436  C2449  2019-09-30  POMILIO MAXIMILIANO OSCAR         34538444
# 2437  C2450  2019-09-30       VILLAR NORBERTO JOSE         16677663
#
#      titular_si                                titular_de_licencia  \
# 0            SI                                      CHAIN ARACELI
# ...
